# %% [markdown]
# <img src="image1.png" alt="drawing" width="800"/>
#
# # Le voyageur Galactique.
# ## L'aventure en quelques clics.
#
# Te voilà dans la peau de Hobber Mallow, le marchand baroudeur de l'espace imaginé par Isaac Asimov dans le cycle Fondation. Tu te réveilles un matin sur la planète Trantor, capitale de l'empire galactique. Ta tête est douloureuse, le mulet, ce mutant capable de manipuler les esprits a effacé une partie de ta mémoire. Il te faut rejoindre la planète Terminus pour alerter les dirigeants de la Fondation. Mais comment faire? Ton vaisseau, le Far Star, a été confisqué par les forces de l'Empire. Tu vas devoir emprunter les transports en commun !. C'est là que l'aventure commence.
#
# **Matériel** : du papier, un crayon, un peu de patience, et ce notebook !
#
# **Règle du jeu** : Au départ du jeu tu es sur la planète Trantor désignée par la "A" et tu dois trouver un chemin pour te rendre sur Terminus désignée par "Z".
#
# **Tu disposes de 3 commandes**
# _Rappel :pour exécuter le code d'une cellule il faut se placer sur la cellule et Maj+Entrée_
#
# 1. destinations
# ```python
# destinations("A")
# ```
# te permet d'obtenir la liste des planètes que tu peux atteindre depuis "A" en utilisant les lignes régulières de la compagnie Empire Space Lines. Ces destinations deviendront des planètes _découvertes_.
#
# Si tu tentes d'obtenir les destinations à partir d'une planète non découverte tu obtiens un message d'erreur.
#
# 2. conseil
# ```python
# conseil()
# ```
# Cette commande va te donner des conseils pour ta recherche si tu es à la peine.
#
# 3. soumettre une solution
# ```python
# verifie_parcours("ABCDE")
# ```
# Vérifie que le chemin de A->B->C->D->E mène de Trantor à Terminus.
# Soumets ta solution quand tu penses l'avoir trouvée.
#
# Pour commencer le jeu tu dois exécuter le code de la cellule suivante qui permet d'importer la carte de la galaxie. (pour exécuter le code d'une cellule il faut se placer sur la cellule et Maj+Entrée)
# ## Lorsque tu as terminé tu peux aller lire le [cours](./cours_partie1.ipynb)

# %%
from galaxie import *  # Maj+Entrée exécute le code et crée une nouvelle cellule
